# %%
import numpy as np
import pandas as pd
import os 
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import matplotlib.pyplot as plt 

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torch.utils.data.dataloader import DataLoader 
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import transforms
import os
from PIL import Image
import numpy as np
import time

# %%
class CancerCNN(nn.Module):

    def __init__(self, num_classes=5):
        super().__init__()

        # Feature extractor
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)   # 128x128 -> 128x128
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)  # 64x64 -> 64x64
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # 32x32 -> 32x32

        self.pool = nn.MaxPool2d(2, 2)  # halves H,W

        # After 3 pools: 128 -> 64 -> 32 -> 16
        # Channels = 64, spatial = 16x16
        self.fc1 = nn.Linear(64 * 16 * 16, 128)
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # -> 16 x 64 x 64
        x = self.pool(F.relu(self.conv2(x)))  # -> 32 x 32 x 32
        x = self.pool(F.relu(self.conv3(x)))  # -> 64 x 16 x 16

        x = torch.flatten(x, 1)               # -> 64*16*16
        x = F.relu(self.fc1(x))               # -> 128
        x = self.fc2(x)                       # -> logits (5)
        return x
# 2. DATASET CLASS

class CancerDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.samples = []
        
        print(f"Root directory: {root_dir}")
        
        for class_name in self.classes:
            class_dir = os.path.join(root_dir, class_name)
            if os.path.exists(class_dir):
                images = [f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.tif', '.tiff'))]
                for img_name in images[:5000]:  # Used to check if loading works on smaller samples
                    img_path = os.path.join(class_dir, img_name)
                    self.samples.append((img_path, self.class_to_idx[class_name]))
                print(f"  {class_name}: {len(images)} images")
        
        print(f"Total samples loaded: {len(self.samples)}")
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert('RGB')
        
        if self.transform:
            image = self.transform(image)
        
        return image, label


# 3. TRAINING FUNCTION 
def train_with_immediate_output():
      
    print("Traisn MODEL")
     
    
    # Setup
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"\n[SETUP] Device: {device}")
    if device.type == 'cuda':
        print(f"[SETUP] GPU: {torch.cuda.get_device_name(0)}")
        print(f"[SETUP] CUDA Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
    
    # Define transforms
    transform = transforms.Compose([
        transforms.Resize((128, 128)),  # Fixed size
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    
    # Load dataset
    print("\n[DATA] Loading dataset...")
    data_dir = "lungcolon"
    
    if not os.path.exists(data_dir):
        print(f"ERROR: Dataset not found at '{data_dir}'")

        return
    
    # Create dataset
    dataset = CancerDataset(root_dir=data_dir, transform=transform)
    
    # Split dataset (70% train, 15% val, 15% test)
    train_size = int(0.7 * len(dataset))
    val_size = int(0.15 * len(dataset))
    test_size = len(dataset) - train_size - val_size
    
    train_dataset, val_dataset, test_dataset = random_split(
        dataset, [train_size, val_size, test_size],
        generator=torch.Generator().manual_seed(42)
    )
    
    print(f"\n[DATA] Dataset splits:")
    print(f"  Training: {len(train_dataset)} samples")
    print(f"  Validation: {len(val_dataset)} samples")
    print(f"  Test: {len(test_dataset)} samples")
    print(f"  Classes: {dataset.classes}")
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0)  # num_workers=0 for immediate output
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=0)
    
    # Create model
    model = CancerCNN(num_classes=len(dataset.classes)).to(device)
    
      
    print("MODEL ARCHITECTURE")
     
    print(model)
    
    # Calculate parameters
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\n[MODEL] Total parameters: {total_params:,}")
    print(f"[MODEL] Trainable parameters: {trainable_params:,}")
    
    # Training setup
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    
      
    print("TRAINING")
     
    
    
    # Training loop
    num_epochs = 5  # Start with 3 epochs for quick results IF CPU it will take hors 
    model.train()
    
    for epoch in range(num_epochs):
        epoch_start_time = time.time()
        running_loss = 0.0
        correct = 0
        total = 0
        
        print(f"\n[EPOCH {epoch+1}/{num_epochs}] Starting...")
    
        
        # Training batches
        for batch_idx, (images, labels) in enumerate(train_loader):
            batch_start_time = time.time()
            
            # Move to device
            images, labels = images.to(device), labels.to(device)
            
            # Forward pass
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            # Backward pass
            loss.backward()
            optimizer.step()
            
            # Calculate accuracy
            _, predicted = torch.max(outputs.data, 1)
            batch_total = labels.size(0)
            batch_correct = (predicted == labels).sum().item()
            
            # Update statistics
            running_loss += loss.item()
            total += batch_total
            correct += batch_correct
            
            # Print immediate progress
            batch_time = time.time() - batch_start_time
            
            if batch_idx == 0:
                print(f"[BATCH 1] Loss: {loss.item():.4f}, Acc: {100*batch_correct/batch_total:.1f}%, Time: {batch_time:.1f}s")
                print(f"[INFO] First batch completed! Training continues...")
            elif (batch_idx + 1) % 10 == 0:  # Print every 10 batches
                avg_loss = running_loss / (batch_idx + 1)
                current_acc = 100 * correct / total
                print(f"[BATCH {batch_idx+1}] Avg Loss: {avg_loss:.4f}, Current Acc: {current_acc:.1f}%")
        
        # Epoch statistics
        epoch_time = time.time() - epoch_start_time
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = 100 * correct / total
        
        print(f"\n[EPOCH {epoch+1} SUMMARY]")
        print(f"  Loss: {epoch_loss:.4f}")
        print(f"  Accuracy: {epoch_acc:.2f}%")
        print(f"  Time: {epoch_time:.1f} seconds")
        
        # Validation
        model.eval()
        val_correct = 0
        val_total = 0
        val_loss = 0.0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()
        
        val_acc = 100 * val_correct / val_total
        avg_val_loss = val_loss / len(val_loader)
        
        print(f"[VALIDATION] Loss: {avg_val_loss:.4f}, Accuracy: {val_acc:.2f}%")
        
        
        model.train()  # Set back to training mode
    
    # Save model
    torch.save({
        'model_state_dict': model.state_dict(),
        'epochs': num_epochs,
        'loss': epoch_loss,
        'accuracy': epoch_acc,
        'classes': dataset.classes
    }, 'cancer_cnn_model.pth')
    
    print(f"\n" + "="*70)
    print("TRAINING COMPLETE!")
     
    print(f"Model saved as 'cancer_cnn_model.pth'")
    print(f"Final Training Accuracy: {epoch_acc:.2f}%")
    print(f"Final Validation Accuracy: {val_acc:.2f}%")
    print(f"Total training time: {time.time() - start_time:.1f} seconds")
    
    return model


# 5. MAIN 
if __name__ == "__main__":
    start_time = time.time()
    
      
    print("CANCER HISTOPATHOLOGY CNN CLASSIFIER")
     
    
    # Step 1: Quick test
    print("\n Running quick CNN connection test...")
    #quick_test()
    
    # Step 2: Training
    print("\n Starting actual training...")
    
    try:
        model = train_with_immediate_output()
        
          
        
    except Exception as e:
       print (f"ERROR")
# Out:
# CANCER HISTOPATHOLOGY CNN CLASSIFIER
#
#  Running quick CNN connection test...
#
#  Starting actual training...
# Traisn MODEL
#
# [SETUP] Device: cuda
# [SETUP] GPU: NVIDIA GeForce RTX 3080 Laptop GPU
# [SETUP] CUDA Memory: 8.6 GB
#
# [DATA] Loading dataset...
# Root directory: lungcolon
#   colon_aca: 5000 images
#   colon_n: 5000 images
#   lung_aca: 5000 images
#   lung_n: 5000 images
#   lung_scc: 5000 images
# Total samples loaded: 25000
#
# [DATA] Dataset splits:
#   Training: 17500 samples
#   Validation: 3750 samples
#   Test: 3750 samples
#   Classes: ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']
# MODEL ARCHITECTURE
# CancerCNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=16384, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=5, bias=True)
# )
#
# [MODEL] Total parameters: 2,121,509
# [MODEL] Trainable parameters: 2,121,509
# TRAINING
#
# [EPOCH 1/5] Starting...
# [BATCH 1] Loss: 1.6159, Acc: 21.9%, Time: 0.8s
# [INFO] First batch completed! Training continues...
# [BATCH 10] Avg Loss: 1.3674, Current Acc: 36.2%
# [BATCH 20] Avg Loss: 1.1278, Current Acc: 45.5%
# [BATCH 30] Avg Loss: 0.9905, Current Acc: 52.4%
# [BATCH 40] Avg Loss: 0.9085, Current Acc: 55.4%
# [BATCH 50] Avg Loss: 0.8345, Current Acc: 59.1%
# [BATCH 60] Avg Loss: 0.7817, Current Acc: 62.2%
# [BATCH 70] Avg Loss: 0.7387, Current Acc: 64.7%
# [BATCH 80] Avg Loss: 0.7114, Current Acc: 66.0%
# [BATCH 90] Avg Loss: 0.6808, Current Acc: 67.8%
# [BATCH 100] Avg Loss: 0.6555, Current Acc: 69.2%
# [BATCH 110] Avg Loss: 0.6356, Current Acc: 70.4%
# [BATCH 120] Avg Loss: 0.6209, Current Acc: 70.9%
# [BATCH 130] Avg Loss: 0.6061, Current Acc: 71.8%
# [BATCH 140] Avg Loss: 0.5900, Current Acc: 72.7%
# [BATCH 150] Avg Loss: 0.5781, Current Acc: 73.3%
# [BATCH 160] Avg Loss: 0.5676, Current Acc: 73.8%
# [BATCH 170] Avg Loss: 0.5601, Current Acc: 74.2%
# [BATCH 180] Avg Loss: 0.5504, Current Acc: 74.7%
# [BATCH 190] Avg Loss: 0.5397, Current Acc: 75.3%
# [BATCH 200] Avg Loss: 0.5353, Current Acc: 75.4%
# [BATCH 210] Avg Loss: 0.5308, Current Acc: 75.4%
# [BATCH 220] Avg Loss: 0.5255, Current Acc: 75.7%
# [BATCH 230] Avg Loss: 0.5203, Current Acc: 75.9%
# [BATCH 240] Avg Loss: 0.5134, Current Acc: 76.3%
# [BATCH 250] Avg Loss: 0.5049, Current Acc: 76.8%
# [BATCH 260] Avg Loss: 0.4994, Current Acc: 77.1%
# [BATCH 270] Avg Loss: 0.4942, Current Acc: 77.4%
# [BATCH 280] Avg Loss: 0.4866, Current Acc: 77.8%
# [BATCH 290] Avg Loss: 0.4787, Current Acc: 78.3%
# [BATCH 300] Avg Loss: 0.4713, Current Acc: 78.6%
# [BATCH 310] Avg Loss: 0.4663, Current Acc: 78.9%
# [BATCH 320] Avg Loss: 0.4618, Current Acc: 79.2%
# [BATCH 330] Avg Loss: 0.4586, Current Acc: 79.4%
# [BATCH 340] Avg Loss: 0.4583, Current Acc: 79.4%
# [BATCH 350] Avg Loss: 0.4562, Current Acc: 79.5%
# [BATCH 360] Avg Loss: 0.4556, Current Acc: 79.6%
# [BATCH 370] Avg Loss: 0.4512, Current Acc: 79.8%
# [BATCH 380] Avg Loss: 0.4462, Current Acc: 80.1%
# [BATCH 390] Avg Loss: 0.4412, Current Acc: 80.3%
# [BATCH 400] Avg Loss: 0.4363, Current Acc: 80.6%
# [BATCH 410] Avg Loss: 0.4322, Current Acc: 80.7%
# [BATCH 420] Avg Loss: 0.4304, Current Acc: 80.9%
# [BATCH 430] Avg Loss: 0.4305, Current Acc: 80.9%
# [BATCH 440] Avg Loss: 0.4315, Current Acc: 80.8%
# [BATCH 450] Avg Loss: 0.4296, Current Acc: 81.0%
# [BATCH 460] Avg Loss: 0.4269, Current Acc: 81.1%
# [BATCH 470] Avg Loss: 0.4227, Current Acc: 81.3%
# [BATCH 480] Avg Loss: 0.4196, Current Acc: 81.5%
# [BATCH 490] Avg Loss: 0.4156, Current Acc: 81.7%
# [BATCH 500] Avg Loss: 0.4127, Current Acc: 81.8%
# [BATCH 510] Avg Loss: 0.4088, Current Acc: 82.0%
# [BATCH 520] Avg Loss: 0.4080, Current Acc: 82.0%
# [BATCH 530] Avg Loss: 0.4052, Current Acc: 82.1%
# [BATCH 540] Avg Loss: 0.4026, Current Acc: 82.2%
#
# [EPOCH 1 SUMMARY]
#   Loss: 0.4013
#   Accuracy: 82.30%
#   Time: 533.5 seconds
# [VALIDATION] Loss: 0.2361, Accuracy: 89.57%
#
# [EPOCH 2/5] Starting...
# [BATCH 1] Loss: 0.2975, Acc: 87.5%, Time: 0.1s
# [INFO] First batch completed! Training continues...
# [BATCH 10] Avg Loss: 0.2701, Current Acc: 89.1%
# [BATCH 20] Avg Loss: 0.2552, Current Acc: 90.0%
# [BATCH 30] Avg Loss: 0.2405, Current Acc: 90.3%
# [BATCH 40] Avg Loss: 0.2449, Current Acc: 89.8%
# [BATCH 50] Avg Loss: 0.2463, Current Acc: 89.8%
# [BATCH 60] Avg Loss: 0.2422, Current Acc: 90.2%
# [BATCH 70] Avg Loss: 0.2383, Current Acc: 90.3%
# [BATCH 80] Avg Loss: 0.2350, Current Acc: 90.5%
# [BATCH 90] Avg Loss: 0.2340, Current Acc: 90.5%
# [BATCH 100] Avg Loss: 0.2360, Current Acc: 90.3%
# [BATCH 110] Avg Loss: 0.2433, Current Acc: 90.2%
# [BATCH 120] Avg Loss: 0.2470, Current Acc: 90.1%
# [BATCH 130] Avg Loss: 0.2469, Current Acc: 90.0%
# [BATCH 140] Avg Loss: 0.2455, Current Acc: 90.0%
# [BATCH 150] Avg Loss: 0.2429, Current Acc: 90.1%
# [BATCH 160] Avg Loss: 0.2368, Current Acc: 90.4%
# [BATCH 170] Avg Loss: 0.2390, Current Acc: 90.3%
# [BATCH 180] Avg Loss: 0.2413, Current Acc: 90.2%
# [BATCH 190] Avg Loss: 0.2399, Current Acc: 90.2%
# [BATCH 200] Avg Loss: 0.2402, Current Acc: 90.2%
# [BATCH 210] Avg Loss: 0.2379, Current Acc: 90.3%
# [BATCH 220] Avg Loss: 0.2395, Current Acc: 90.2%
# [BATCH 230] Avg Loss: 0.2404, Current Acc: 90.2%
# [BATCH 240] Avg Loss: 0.2396, Current Acc: 90.2%
# [BATCH 250] Avg Loss: 0.2389, Current Acc: 90.2%
# [BATCH 260] Avg Loss: 0.2363, Current Acc: 90.3%
# [BATCH 270] Avg Loss: 0.2357, Current Acc: 90.4%
# [BATCH 280] Avg Loss: 0.2344, Current Acc: 90.4%
# [BATCH 290] Avg Loss: 0.2330, Current Acc: 90.5%
# [BATCH 300] Avg Loss: 0.2313, Current Acc: 90.6%
# [BATCH 310] Avg Loss: 0.2286, Current Acc: 90.7%
# [BATCH 320] Avg Loss: 0.2266, Current Acc: 90.8%
# [BATCH 330] Avg Loss: 0.2265, Current Acc: 90.8%
# [BATCH 340] Avg Loss: 0.2249, Current Acc: 90.9%
# [BATCH 350] Avg Loss: 0.2236, Current Acc: 90.9%
# [BATCH 360] Avg Loss: 0.2232, Current Acc: 91.0%
# [BATCH 370] Avg Loss: 0.2224, Current Acc: 91.0%
# [BATCH 380] Avg Loss: 0.2225, Current Acc: 90.9%
# [BATCH 390] Avg Loss: 0.2223, Current Acc: 90.9%
# [BATCH 400] Avg Loss: 0.2221, Current Acc: 90.9%
# [BATCH 410] Avg Loss: 0.2228, Current Acc: 90.9%
# [BATCH 420] Avg Loss: 0.2222, Current Acc: 90.9%
# [BATCH 430] Avg Loss: 0.2223, Current Acc: 90.9%
# [BATCH 440] Avg Loss: 0.2213, Current Acc: 91.0%
# [BATCH 450] Avg Loss: 0.2199, Current Acc: 91.0%
# [BATCH 460] Avg Loss: 0.2196, Current Acc: 91.1%
# [BATCH 470] Avg Loss: 0.2185, Current Acc: 91.1%
# [BATCH 480] Avg Loss: 0.2179, Current Acc: 91.2%
# [BATCH 490] Avg Loss: 0.2168, Current Acc: 91.2%
# [BATCH 500] Avg Loss: 0.2154, Current Acc: 91.3%
# [BATCH 510] Avg Loss: 0.2140, Current Acc: 91.4%
# [BATCH 520] Avg Loss: 0.2137, Current Acc: 91.4%
# [BATCH 530] Avg Loss: 0.2132, Current Acc: 91.4%
# [BATCH 540] Avg Loss: 0.2125, Current Acc: 91.4%
#
# [EPOCH 2 SUMMARY]
#   Loss: 0.2117
#   Accuracy: 91.50%
#   Time: 391.0 seconds
# [VALIDATION] Loss: 0.2161, Accuracy: 91.52%
#
# [EPOCH 3/5] Starting...
# [BATCH 1] Loss: 0.0517, Acc: 96.9%, Time: 0.1s
# [INFO] First batch completed! Training continues...
# [BATCH 10] Avg Loss: 0.1406, Current Acc: 93.8%
# [BATCH 20] Avg Loss: 0.1473, Current Acc: 93.6%
# [BATCH 30] Avg Loss: 0.1350, Current Acc: 94.8%
# [BATCH 40] Avg Loss: 0.1265, Current Acc: 95.3%
# [BATCH 50] Avg Loss: 0.1240, Current Acc: 95.4%
# [BATCH 60] Avg Loss: 0.1346, Current Acc: 95.1%
# [BATCH 70] Avg Loss: 0.1322, Current Acc: 95.0%
# [BATCH 80] Avg Loss: 0.1370, Current Acc: 94.8%
# [BATCH 90] Avg Loss: 0.1369, Current Acc: 94.7%
# [BATCH 100] Avg Loss: 0.1353, Current Acc: 94.7%
# [BATCH 110] Avg Loss: 0.1330, Current Acc: 94.8%
# [BATCH 120] Avg Loss: 0.1309, Current Acc: 94.7%
# [BATCH 130] Avg Loss: 0.1338, Current Acc: 94.7%
# [BATCH 140] Avg Loss: 0.1394, Current Acc: 94.4%
# [BATCH 150] Avg Loss: 0.1472, Current Acc: 94.1%
# [BATCH 160] Avg Loss: 0.1458, Current Acc: 94.2%
# [BATCH 170] Avg Loss: 0.1440, Current Acc: 94.2%
# [BATCH 180] Avg Loss: 0.1419, Current Acc: 94.3%
# [BATCH 190] Avg Loss: 0.1406, Current Acc: 94.4%
# [BATCH 200] Avg Loss: 0.1404, Current Acc: 94.4%
# [BATCH 210] Avg Loss: 0.1430, Current Acc: 94.3%
# [BATCH 220] Avg Loss: 0.1440, Current Acc: 94.3%
# [BATCH 230] Avg Loss: 0.1438, Current Acc: 94.3%
# [BATCH 240] Avg Loss: 0.1435, Current Acc: 94.3%
# [BATCH 250] Avg Loss: 0.1439, Current Acc: 94.3%
# [BATCH 260] Avg Loss: 0.1442, Current Acc: 94.4%
# [BATCH 270] Avg Loss: 0.1452, Current Acc: 94.3%
# [BATCH 280] Avg Loss: 0.1463, Current Acc: 94.2%
# [BATCH 290] Avg Loss: 0.1467, Current Acc: 94.2%
# [BATCH 300] Avg Loss: 0.1452, Current Acc: 94.3%
# [BATCH 310] Avg Loss: 0.1455, Current Acc: 94.3%
# [BATCH 320] Avg Loss: 0.1438, Current Acc: 94.3%
# [BATCH 330] Avg Loss: 0.1437, Current Acc: 94.3%
# [BATCH 340] Avg Loss: 0.1413, Current Acc: 94.4%
# [BATCH 350] Avg Loss: 0.1393, Current Acc: 94.5%
# [BATCH 360] Avg Loss: 0.1389, Current Acc: 94.5%
# [BATCH 370] Avg Loss: 0.1384, Current Acc: 94.6%
# [BATCH 380] Avg Loss: 0.1368, Current Acc: 94.6%
# [BATCH 390] Avg Loss: 0.1368, Current Acc: 94.6%
# [BATCH 400] Avg Loss: 0.1365, Current Acc: 94.6%
# [BATCH 410] Avg Loss: 0.1360, Current Acc: 94.6%
# [BATCH 420] Avg Loss: 0.1351, Current Acc: 94.7%
# [BATCH 430] Avg Loss: 0.1341, Current Acc: 94.7%
# [BATCH 440] Avg Loss: 0.1335, Current Acc: 94.8%
# [BATCH 450] Avg Loss: 0.1330, Current Acc: 94.8%
# [BATCH 460] Avg Loss: 0.1328, Current Acc: 94.8%
# [BATCH 470] Avg Loss: 0.1331, Current Acc: 94.7%
# [BATCH 480] Avg Loss: 0.1330, Current Acc: 94.7%
# [BATCH 490] Avg Loss: 0.1324, Current Acc: 94.8%
# [BATCH 500] Avg Loss: 0.1313, Current Acc: 94.8%
# [BATCH 510] Avg Loss: 0.1304, Current Acc: 94.9%
# [BATCH 520] Avg Loss: 0.1292, Current Acc: 94.9%
# [BATCH 530] Avg Loss: 0.1286, Current Acc: 95.0%
# [BATCH 540] Avg Loss: 0.1273, Current Acc: 95.0%
#
# [EPOCH 3 SUMMARY]
#   Loss: 0.1264
#   Accuracy: 95.09%
#   Time: 377.7 seconds
# [VALIDATION] Loss: 0.1479, Accuracy: 94.61%
#
# [EPOCH 4/5] Starting...
# [BATCH 1] Loss: 0.0102, Acc: 100.0%, Time: 0.1s
# [INFO] First batch completed! Training continues...
# [BATCH 10] Avg Loss: 0.0665, Current Acc: 97.2%
# [BATCH 20] Avg Loss: 0.0821, Current Acc: 96.4%
# [BATCH 30] Avg Loss: 0.0945, Current Acc: 96.1%
# [BATCH 40] Avg Loss: 0.0921, Current Acc: 96.5%
# [BATCH 50] Avg Loss: 0.0842, Current Acc: 97.0%
# [BATCH 60] Avg Loss: 0.0859, Current Acc: 96.8%
# [BATCH 70] Avg Loss: 0.0832, Current Acc: 97.0%
# [BATCH 80] Avg Loss: 0.0784, Current Acc: 97.1%
# [BATCH 90] Avg Loss: 0.0748, Current Acc: 97.4%
# [BATCH 100] Avg Loss: 0.0737, Current Acc: 97.5%
# [BATCH 110] Avg Loss: 0.0726, Current Acc: 97.5%
# [BATCH 120] Avg Loss: 0.0720, Current Acc: 97.5%
# [BATCH 130] Avg Loss: 0.0792, Current Acc: 97.2%
# [BATCH 140] Avg Loss: 0.0783, Current Acc: 97.2%
# [BATCH 150] Avg Loss: 0.0814, Current Acc: 96.9%
# [BATCH 160] Avg Loss: 0.0806, Current Acc: 97.0%
# [BATCH 170] Avg Loss: 0.0811, Current Acc: 96.9%
# [BATCH 180] Avg Loss: 0.0792, Current Acc: 97.0%
# [BATCH 190] Avg Loss: 0.0819, Current Acc: 96.8%
# [BATCH 200] Avg Loss: 0.0823, Current Acc: 96.8%
# [BATCH 210] Avg Loss: 0.0819, Current Acc: 96.9%
# [BATCH 220] Avg Loss: 0.0812, Current Acc: 96.9%
# [BATCH 230] Avg Loss: 0.0802, Current Acc: 97.0%
# [BATCH 240] Avg Loss: 0.0799, Current Acc: 97.0%
# [BATCH 250] Avg Loss: 0.0791, Current Acc: 97.0%
# [BATCH 260] Avg Loss: 0.0788, Current Acc: 97.0%
# [BATCH 270] Avg Loss: 0.0781, Current Acc: 97.0%
# [BATCH 280] Avg Loss: 0.0778, Current Acc: 97.1%
# [BATCH 290] Avg Loss: 0.0773, Current Acc: 97.1%
# [BATCH 300] Avg Loss: 0.0762, Current Acc: 97.1%
# [BATCH 310] Avg Loss: 0.0763, Current Acc: 97.1%
# [BATCH 320] Avg Loss: 0.0761, Current Acc: 97.1%
# [BATCH 330] Avg Loss: 0.0762, Current Acc: 97.1%
# [BATCH 340] Avg Loss: 0.0766, Current Acc: 97.0%
# [BATCH 350] Avg Loss: 0.0757, Current Acc: 97.1%
# [BATCH 360] Avg Loss: 0.0754, Current Acc: 97.1%
# [BATCH 370] Avg Loss: 0.0754, Current Acc: 97.1%
# [BATCH 380] Avg Loss: 0.0751, Current Acc: 97.1%
# [BATCH 390] Avg Loss: 0.0752, Current Acc: 97.1%
# [BATCH 400] Avg Loss: 0.0749, Current Acc: 97.1%
# [BATCH 410] Avg Loss: 0.0740, Current Acc: 97.1%
# [BATCH 420] Avg Loss: 0.0734, Current Acc: 97.2%
# [BATCH 430] Avg Loss: 0.0732, Current Acc: 97.2%
# [BATCH 440] Avg Loss: 0.0728, Current Acc: 97.2%
# [BATCH 450] Avg Loss: 0.0726, Current Acc: 97.2%
# [BATCH 460] Avg Loss: 0.0726, Current Acc: 97.2%
# [BATCH 470] Avg Loss: 0.0733, Current Acc: 97.2%
# [BATCH 480] Avg Loss: 0.0735, Current Acc: 97.2%
# [BATCH 490] Avg Loss: 0.0737, Current Acc: 97.2%
# [BATCH 500] Avg Loss: 0.0739, Current Acc: 97.2%
# [BATCH 510] Avg Loss: 0.0745, Current Acc: 97.1%
# [BATCH 520] Avg Loss: 0.0744, Current Acc: 97.1%
# [BATCH 530] Avg Loss: 0.0736, Current Acc: 97.2%
# [BATCH 540] Avg Loss: 0.0736, Current Acc: 97.2%
#
# [EPOCH 4 SUMMARY]
#   Loss: 0.0741
#   Accuracy: 97.15%
#   Time: 378.0 seconds
# [VALIDATION] Loss: 0.1694, Accuracy: 93.65%
#
# [EPOCH 5/5] Starting...
# [BATCH 1] Loss: 0.0419, Acc: 96.9%, Time: 0.1s
# [INFO] First batch completed! Training continues...
# [BATCH 10] Avg Loss: 0.0777, Current Acc: 96.9%
# [BATCH 20] Avg Loss: 0.0625, Current Acc: 97.8%
# [BATCH 30] Avg Loss: 0.0542, Current Acc: 98.3%
# [BATCH 40] Avg Loss: 0.0495, Current Acc: 98.4%
# [BATCH 50] Avg Loss: 0.0479, Current Acc: 98.4%
# [BATCH 60] Avg Loss: 0.0446, Current Acc: 98.6%
# [BATCH 70] Avg Loss: 0.0462, Current Acc: 98.5%
# [BATCH 80] Avg Loss: 0.0470, Current Acc: 98.5%
# [BATCH 90] Avg Loss: 0.0450, Current Acc: 98.6%
# [BATCH 100] Avg Loss: 0.0460, Current Acc: 98.5%
# [BATCH 110] Avg Loss: 0.0459, Current Acc: 98.5%
# [BATCH 120] Avg Loss: 0.0460, Current Acc: 98.5%
# [BATCH 130] Avg Loss: 0.0461, Current Acc: 98.4%
# [BATCH 140] Avg Loss: 0.0440, Current Acc: 98.5%
# [BATCH 150] Avg Loss: 0.0445, Current Acc: 98.5%
# [BATCH 160] Avg Loss: 0.0448, Current Acc: 98.4%
# [BATCH 170] Avg Loss: 0.0456, Current Acc: 98.4%
# [BATCH 180] Avg Loss: 0.0466, Current Acc: 98.3%
# [BATCH 190] Avg Loss: 0.0458, Current Acc: 98.4%
# [BATCH 200] Avg Loss: 0.0469, Current Acc: 98.3%
# [BATCH 210] Avg Loss: 0.0462, Current Acc: 98.3%
# [BATCH 220] Avg Loss: 0.0459, Current Acc: 98.4%
# [BATCH 230] Avg Loss: 0.0458, Current Acc: 98.4%
# [BATCH 240] Avg Loss: 0.0450, Current Acc: 98.4%
# [BATCH 250] Avg Loss: 0.0449, Current Acc: 98.4%
# [BATCH 260] Avg Loss: 0.0441, Current Acc: 98.4%
# [BATCH 270] Avg Loss: 0.0438, Current Acc: 98.4%
# [BATCH 280] Avg Loss: 0.0439, Current Acc: 98.4%
# [BATCH 290] Avg Loss: 0.0443, Current Acc: 98.4%
# [BATCH 300] Avg Loss: 0.0459, Current Acc: 98.4%
# [BATCH 310] Avg Loss: 0.0460, Current Acc: 98.4%
# [BATCH 320] Avg Loss: 0.0460, Current Acc: 98.4%
# [BATCH 330] Avg Loss: 0.0458, Current Acc: 98.4%
# [BATCH 340] Avg Loss: 0.0450, Current Acc: 98.4%
# [BATCH 350] Avg Loss: 0.0448, Current Acc: 98.4%
# [BATCH 360] Avg Loss: 0.0446, Current Acc: 98.4%
# [BATCH 370] Avg Loss: 0.0451, Current Acc: 98.4%
# [BATCH 380] Avg Loss: 0.0459, Current Acc: 98.4%
# [BATCH 390] Avg Loss: 0.0464, Current Acc: 98.4%
# [BATCH 400] Avg Loss: 0.0468, Current Acc: 98.3%
# [BATCH 410] Avg Loss: 0.0465, Current Acc: 98.3%
# [BATCH 420] Avg Loss: 0.0459, Current Acc: 98.4%
# [BATCH 430] Avg Loss: 0.0454, Current Acc: 98.4%
# [BATCH 440] Avg Loss: 0.0453, Current Acc: 98.4%
# [BATCH 450] Avg Loss: 0.0449, Current Acc: 98.4%
# [BATCH 460] Avg Loss: 0.0445, Current Acc: 98.4%
# [BATCH 470] Avg Loss: 0.0444, Current Acc: 98.4%
# [BATCH 480] Avg Loss: 0.0455, Current Acc: 98.4%
# [BATCH 490] Avg Loss: 0.0460, Current Acc: 98.4%
# [BATCH 500] Avg Loss: 0.0470, Current Acc: 98.3%
# [BATCH 510] Avg Loss: 0.0480, Current Acc: 98.3%
# [BATCH 520] Avg Loss: 0.0489, Current Acc: 98.2%
# [BATCH 530] Avg Loss: 0.0505, Current Acc: 98.2%
# [BATCH 540] Avg Loss: 0.0513, Current Acc: 98.2%
#
# [EPOCH 5 SUMMARY]
#   Loss: 0.0509
#   Accuracy: 98.19%
#   Time: 378.6 seconds
# [VALIDATION] Loss: 0.1226, Accuracy: 95.57%
#
# ======================================================================
# TRAINING COMPLETE!
# Model saved as 'cancer_cnn_model.pth'
# Final Training Accuracy: 98.19%
# Final Validation Accuracy: 95.57%
# Total training time: 2436.7 seconds
