# %%
import numpy as np
import pandas as pd
import os 
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import matplotlib.pyplot as plt 

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torch.utils.data.dataloader import DataLoader

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import transforms
import os
from PIL import Image
import numpy as np
import time


class CancerCNN(nn.Module):
    def __init__(self, num_classes=5, dropout_rate=0.5):
        super().__init__()
        
        # Feature extractor
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)   # 128x128 -> 128x128
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)  # 64x64 -> 64x64
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # 32x32 -> 32x32
        
        self.pool = nn.MaxPool2d(2, 2)  # halves H,W
        
        # Dropout layers
        self.dropout2d = nn.Dropout2d(p=0.25)  # Spatial dropout for convolutional layers
        self.dropout = nn.Dropout(p=dropout_rate)  # Standard dropout for fully connected
        
        # After 3 pools: 128 -> 64 -> 32 -> 16
        # Channels = 64, spatial = 16x16
        self.fc1 = nn.Linear(64 * 16 * 16, 128)
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        # Conv block 1 with spatial dropout
        x = self.pool(F.relu(self.conv1(x)))  # -> 16 x 64 x 64
        x = self.dropout2d(x)  # Spatial dropout
        
        # Conv block 2 with spatial dropout
        x = self.pool(F.relu(self.conv2(x)))  # -> 32 x 32 x 32
        x = self.dropout2d(x)  # Spatial dropout
        
        # Conv block 3 with spatial dropout
        x = self.pool(F.relu(self.conv3(x)))  # -> 64 x 16 x 16
        x = self.dropout2d(x)  # Spatial dropout
        
        x = torch.flatten(x, 1)               # -> 64*16*16
        x = F.relu(self.fc1(x))               # -> 128
        x = self.dropout(x)                   # Dropout before final layer
        x = self.fc2(x)                       # -> logits (5)
        return x
# 2. DATASET CLASS

class CancerDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.samples = []
        
        print(f"Root directory: {root_dir}")
        
        for class_name in self.classes:
            class_dir = os.path.join(root_dir, class_name)
            if os.path.exists(class_dir):
                images = [f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.tif', '.tiff'))]
                for img_name in images[:5000]:  # Used to check if loading works on smaller samples
                    img_path = os.path.join(class_dir, img_name)
                    self.samples.append((img_path, self.class_to_idx[class_name]))
                print(f"  {class_name}: {len(images)} images")
        
        print(f"Total samples loaded: {len(self.samples)}")
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert('RGB')
        
        if self.transform:
            image = self.transform(image)
        
        return image, label


# 3. TRAINING FUNCTION 
def train_with_immediate_output():
      
    print("Traisn MODEL")
     
    
    # Setup
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"\n[SETUP] Device: {device}")
    if device.type == 'cuda':
        print(f"[SETUP] GPU: {torch.cuda.get_device_name(0)}")
        print(f"[SETUP] CUDA Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
    
    # Define transforms
    transform = transforms.Compose([
        transforms.Resize((128, 128)),  # Fixed size
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    
    # Load dataset
    print("\n[DATA] Loading dataset...")
    data_dir = "lungcolon"
    
    if not os.path.exists(data_dir):
        print(f"ERROR: Dataset not found at '{data_dir}'")

        return
    
    # Create dataset
    dataset = CancerDataset(root_dir=data_dir, transform=transform)
    
    # Split dataset (70% train, 15% val, 15% test)
    train_size = int(0.7 * len(dataset))
    val_size = int(0.15 * len(dataset))
    test_size = len(dataset) - train_size - val_size
    
    train_dataset, val_dataset, test_dataset = random_split(
        dataset, [train_size, val_size, test_size],
        generator=torch.Generator().manual_seed(42)
    )
    
    print(f"\n[DATA] Dataset splits:")
    print(f"  Training: {len(train_dataset)} samples")
    print(f"  Validation: {len(val_dataset)} samples")
    print(f"  Test: {len(test_dataset)} samples")
    print(f"  Classes: {dataset.classes}")
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0)  # num_workers=0 for immediate output
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=0)
    
    # Create model
    model = CancerCNN(num_classes=len(dataset.classes)).to(device)
    
      
    print("MODEL ARCHITECTURE")
     
    print(model)
    
    # Calculate parameters
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\n[MODEL] Total parameters: {total_params:,}")
    print(f"[MODEL] Trainable parameters: {trainable_params:,}")
    
    # Training setup
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    
      
    print("TRAINING")
     
    
    
    # Training loop
    num_epochs = 5  # Start with 3 epochs for quick results IF CPU it will take hors 
    model.train()
    
    for epoch in range(num_epochs):
        epoch_start_time = time.time()
        running_loss = 0.0
        correct = 0
        total = 0
        
        print(f"\n[EPOCH {epoch+1}/{num_epochs}] Starting...")
    
        
        # Training batches
        for batch_idx, (images, labels) in enumerate(train_loader):
            batch_start_time = time.time()
            
            # Move to device
            images, labels = images.to(device), labels.to(device)
            
            # Forward pass
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            # Backward pass
            loss.backward()
            optimizer.step()
            
            # Calculate accuracy
            _, predicted = torch.max(outputs.data, 1)
            batch_total = labels.size(0)
            batch_correct = (predicted == labels).sum().item()
            
            # Update statistics
            running_loss += loss.item()
            total += batch_total
            correct += batch_correct
            
            # Print immediate progress
            batch_time = time.time() - batch_start_time
            
            if batch_idx == 0:
                print(f"[BATCH 1] Loss: {loss.item():.4f}, Acc: {100*batch_correct/batch_total:.1f}%, Time: {batch_time:.1f}s")
                print(f"[INFO] First batch completed! Training continues...")
            elif (batch_idx + 1) % 10 == 0:  # Print every 10 batches
                avg_loss = running_loss / (batch_idx + 1)
                current_acc = 100 * correct / total
                print(f"[BATCH {batch_idx+1}] Avg Loss: {avg_loss:.4f}, Current Acc: {current_acc:.1f}%")
        
        # Epoch statistics
        epoch_time = time.time() - epoch_start_time
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = 100 * correct / total
        
        print(f"\n[EPOCH {epoch+1} SUMMARY]")
        print(f"  Loss: {epoch_loss:.4f}")
        print(f"  Accuracy: {epoch_acc:.2f}%")
        print(f"  Time: {epoch_time:.1f} seconds")
        
        # Validation
        model.eval()
        val_correct = 0
        val_total = 0
        val_loss = 0.0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()
        
        val_acc = 100 * val_correct / val_total
        avg_val_loss = val_loss / len(val_loader)
        
        print(f"[VALIDATION] Loss: {avg_val_loss:.4f}, Accuracy: {val_acc:.2f}%")
        
        
        model.train()  # Set back to training mode
    
    # Save model
    torch.save({
        'model_state_dict': model.state_dict(),
        'epochs': num_epochs,
        'loss': epoch_loss,
        'accuracy': epoch_acc,
        'classes': dataset.classes
    }, 'cancer_cnn_model.pth')
    
    print(f"\n" + "="*70)
    print("TRAINING COMPLETE!")
     
    print(f"Model saved as 'cancer_cnn_model.pth'")
    print(f"Final Training Accuracy: {epoch_acc:.2f}%")
    print(f"Final Validation Accuracy: {val_acc:.2f}%")
    print(f"Total training time: {time.time() - start_time:.1f} seconds")
    
    return model


# 5. MAIN 
if __name__ == "__main__":
    start_time = time.time()
    
      
    print("CANCER HISTOPATHOLOGY CNN CLASSIFIER")
     
    
    # Step 1: Quick test
    print("\n Running quick CNN connection test...")
    #quick_test()
    
    # Step 2: Training
    print("\n Starting actual training...")
    
    
    try:
        model = train_with_immediate_output()
        
          
        
    except Exception as e:
       print (f"ERROR")
# Out:
# CANCER HISTOPATHOLOGY CNN CLASSIFIER
#
#  Running quick CNN connection test...
#
#  Starting actual training...
# Traisn MODEL
#
# [SETUP] Device: cuda
# [SETUP] GPU: NVIDIA GeForce RTX 3080 Laptop GPU
# [SETUP] CUDA Memory: 8.6 GB
#
# [DATA] Loading dataset...
# Root directory: lungcolon
#   colon_aca: 5000 images
#   colon_n: 5000 images
#   lung_aca: 5000 images
#   lung_n: 5000 images
#   lung_scc: 5000 images
# Total samples loaded: 25000
#
# [DATA] Dataset splits:
#   Training: 17500 samples
#   Validation: 3750 samples
#   Test: 3750 samples
#   Classes: ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']
# MODEL ARCHITECTURE
# CancerCNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2d): Dropout2d(p=0.25, inplace=False)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=16384, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=5, bias=True)
# )
#
# [MODEL] Total parameters: 2,121,509
# [MODEL] Trainable parameters: 2,121,509
# TRAINING
#
# [EPOCH 1/5] Starting...
# [BATCH 1] Loss: 1.6088, Acc: 21.9%, Time: 0.1s
# [INFO] First batch completed! Training continues...
# [BATCH 10] Avg Loss: 1.6308, Current Acc: 22.2%
# [BATCH 20] Avg Loss: 1.5613, Current Acc: 26.4%
# [BATCH 30] Avg Loss: 1.4625, Current Acc: 30.6%
# [BATCH 40] Avg Loss: 1.3869, Current Acc: 33.9%
# [BATCH 50] Avg Loss: 1.3260, Current Acc: 36.9%
# [BATCH 60] Avg Loss: 1.2723, Current Acc: 40.0%
# [BATCH 70] Avg Loss: 1.2158, Current Acc: 42.6%
# [BATCH 80] Avg Loss: 1.1779, Current Acc: 44.4%
# [BATCH 90] Avg Loss: 1.1423, Current Acc: 46.0%
# [BATCH 100] Avg Loss: 1.1088, Current Acc: 47.5%
# [BATCH 110] Avg Loss: 1.0734, Current Acc: 49.1%
# [BATCH 120] Avg Loss: 1.0470, Current Acc: 50.2%
# [BATCH 130] Avg Loss: 1.0278, Current Acc: 51.3%
# [BATCH 140] Avg Loss: 1.0068, Current Acc: 52.0%
# [BATCH 150] Avg Loss: 0.9889, Current Acc: 52.5%
# [BATCH 160] Avg Loss: 0.9731, Current Acc: 53.4%
# [BATCH 170] Avg Loss: 0.9543, Current Acc: 54.2%
# [BATCH 180] Avg Loss: 0.9377, Current Acc: 54.9%
# [BATCH 190] Avg Loss: 0.9289, Current Acc: 55.2%
# [BATCH 200] Avg Loss: 0.9139, Current Acc: 55.8%
# [BATCH 210] Avg Loss: 0.8992, Current Acc: 56.4%
# [BATCH 220] Avg Loss: 0.8860, Current Acc: 57.1%
# [BATCH 230] Avg Loss: 0.8765, Current Acc: 57.6%
# [BATCH 240] Avg Loss: 0.8660, Current Acc: 58.1%
# [BATCH 250] Avg Loss: 0.8568, Current Acc: 58.5%
# [BATCH 260] Avg Loss: 0.8487, Current Acc: 58.8%
# [BATCH 270] Avg Loss: 0.8402, Current Acc: 59.1%
# [BATCH 280] Avg Loss: 0.8311, Current Acc: 59.6%
# [BATCH 290] Avg Loss: 0.8220, Current Acc: 59.9%
# [BATCH 300] Avg Loss: 0.8132, Current Acc: 60.3%
# [BATCH 310] Avg Loss: 0.8047, Current Acc: 60.7%
# [BATCH 320] Avg Loss: 0.7973, Current Acc: 61.2%
# [BATCH 330] Avg Loss: 0.7914, Current Acc: 61.5%
# [BATCH 340] Avg Loss: 0.7856, Current Acc: 61.8%
# [BATCH 350] Avg Loss: 0.7792, Current Acc: 62.0%
# [BATCH 360] Avg Loss: 0.7746, Current Acc: 62.3%
# [BATCH 370] Avg Loss: 0.7689, Current Acc: 62.6%
# [BATCH 380] Avg Loss: 0.7626, Current Acc: 62.9%
# [BATCH 390] Avg Loss: 0.7577, Current Acc: 63.0%
# [BATCH 400] Avg Loss: 0.7515, Current Acc: 63.4%
# [BATCH 410] Avg Loss: 0.7478, Current Acc: 63.7%
# [BATCH 420] Avg Loss: 0.7409, Current Acc: 64.0%
# [BATCH 430] Avg Loss: 0.7340, Current Acc: 64.4%
# [BATCH 440] Avg Loss: 0.7289, Current Acc: 64.6%
# [BATCH 450] Avg Loss: 0.7246, Current Acc: 64.7%
# [BATCH 460] Avg Loss: 0.7196, Current Acc: 65.0%
# [BATCH 470] Avg Loss: 0.7157, Current Acc: 65.2%
# [BATCH 480] Avg Loss: 0.7122, Current Acc: 65.4%
# [BATCH 490] Avg Loss: 0.7092, Current Acc: 65.5%
# [BATCH 500] Avg Loss: 0.7057, Current Acc: 65.9%
# [BATCH 510] Avg Loss: 0.7019, Current Acc: 66.0%
# [BATCH 520] Avg Loss: 0.6983, Current Acc: 66.2%
# [BATCH 530] Avg Loss: 0.6948, Current Acc: 66.3%
# [BATCH 540] Avg Loss: 0.6917, Current Acc: 66.5%
#
# [EPOCH 1 SUMMARY]
#   Loss: 0.6895
#   Accuracy: 66.59%
#   Time: 598.0 seconds
# [VALIDATION] Loss: 0.3839, Accuracy: 85.84%
#
# [EPOCH 2/5] Starting...
# [BATCH 1] Loss: 0.3730, Acc: 87.5%, Time: 0.1s
# [INFO] First batch completed! Training continues...
# [BATCH 10] Avg Loss: 0.4671, Current Acc: 80.6%
# [BATCH 20] Avg Loss: 0.4738, Current Acc: 79.4%
# [BATCH 30] Avg Loss: 0.4659, Current Acc: 79.5%
# [BATCH 40] Avg Loss: 0.4783, Current Acc: 79.2%
# [BATCH 50] Avg Loss: 0.4838, Current Acc: 78.3%
# [BATCH 60] Avg Loss: 0.4868, Current Acc: 77.7%
# [BATCH 70] Avg Loss: 0.4886, Current Acc: 77.5%
# [BATCH 80] Avg Loss: 0.4852, Current Acc: 77.5%
# [BATCH 90] Avg Loss: 0.4793, Current Acc: 77.6%
# [BATCH 100] Avg Loss: 0.4875, Current Acc: 77.3%
# [BATCH 110] Avg Loss: 0.4886, Current Acc: 76.8%
# [BATCH 120] Avg Loss: 0.4859, Current Acc: 76.9%
# [BATCH 130] Avg Loss: 0.4815, Current Acc: 77.4%
# [BATCH 140] Avg Loss: 0.4808, Current Acc: 77.6%
# [BATCH 150] Avg Loss: 0.4784, Current Acc: 77.9%
# [BATCH 160] Avg Loss: 0.4884, Current Acc: 77.5%
# [BATCH 170] Avg Loss: 0.4918, Current Acc: 77.2%
# [BATCH 180] Avg Loss: 0.4901, Current Acc: 77.3%
# [BATCH 190] Avg Loss: 0.4897, Current Acc: 77.4%
# [BATCH 200] Avg Loss: 0.4913, Current Acc: 77.3%
# [BATCH 210] Avg Loss: 0.4901, Current Acc: 77.4%
# [BATCH 220] Avg Loss: 0.4901, Current Acc: 77.4%
# [BATCH 230] Avg Loss: 0.4900, Current Acc: 77.4%
# [BATCH 240] Avg Loss: 0.4873, Current Acc: 77.5%
# [BATCH 250] Avg Loss: 0.4876, Current Acc: 77.5%
# [BATCH 260] Avg Loss: 0.4870, Current Acc: 77.5%
# [BATCH 270] Avg Loss: 0.4861, Current Acc: 77.6%
# [BATCH 280] Avg Loss: 0.4841, Current Acc: 77.7%
# [BATCH 290] Avg Loss: 0.4812, Current Acc: 77.9%
# [BATCH 300] Avg Loss: 0.4816, Current Acc: 78.0%
# [BATCH 310] Avg Loss: 0.4815, Current Acc: 78.0%
# [BATCH 320] Avg Loss: 0.4794, Current Acc: 78.2%
# [BATCH 330] Avg Loss: 0.4781, Current Acc: 78.3%
# [BATCH 340] Avg Loss: 0.4776, Current Acc: 78.4%
# [BATCH 350] Avg Loss: 0.4768, Current Acc: 78.5%
# [BATCH 360] Avg Loss: 0.4746, Current Acc: 78.7%
# [BATCH 370] Avg Loss: 0.4730, Current Acc: 78.8%
# [BATCH 380] Avg Loss: 0.4732, Current Acc: 78.8%
# [BATCH 390] Avg Loss: 0.4740, Current Acc: 78.8%
# [BATCH 400] Avg Loss: 0.4733, Current Acc: 78.9%
# [BATCH 410] Avg Loss: 0.4714, Current Acc: 79.0%
# [BATCH 420] Avg Loss: 0.4707, Current Acc: 79.1%
# [BATCH 430] Avg Loss: 0.4710, Current Acc: 79.2%
# [BATCH 440] Avg Loss: 0.4700, Current Acc: 79.1%
# [BATCH 450] Avg Loss: 0.4687, Current Acc: 79.2%
# [BATCH 460] Avg Loss: 0.4687, Current Acc: 79.2%
# [BATCH 470] Avg Loss: 0.4672, Current Acc: 79.4%
# [BATCH 480] Avg Loss: 0.4668, Current Acc: 79.4%
# [BATCH 490] Avg Loss: 0.4666, Current Acc: 79.4%
# [BATCH 500] Avg Loss: 0.4656, Current Acc: 79.5%
# [BATCH 510] Avg Loss: 0.4646, Current Acc: 79.6%
# [BATCH 520] Avg Loss: 0.4637, Current Acc: 79.7%
# [BATCH 530] Avg Loss: 0.4636, Current Acc: 79.6%
# [BATCH 540] Avg Loss: 0.4632, Current Acc: 79.6%
#
# [EPOCH 2 SUMMARY]
#   Loss: 0.4632
#   Accuracy: 79.61%
#   Time: 380.6 seconds
# [VALIDATION] Loss: 0.3374, Accuracy: 83.31%
#
# [EPOCH 3/5] Starting...
# [BATCH 1] Loss: 0.4810, Acc: 71.9%, Time: 0.1s
# [INFO] First batch completed! Training continues...
# [BATCH 10] Avg Loss: 0.4363, Current Acc: 81.2%
# [BATCH 20] Avg Loss: 0.4275, Current Acc: 82.8%
# [BATCH 30] Avg Loss: 0.4281, Current Acc: 82.2%
# [BATCH 40] Avg Loss: 0.4169, Current Acc: 82.8%
# [BATCH 50] Avg Loss: 0.4153, Current Acc: 83.1%
# [BATCH 60] Avg Loss: 0.4108, Current Acc: 83.0%
# [BATCH 70] Avg Loss: 0.4061, Current Acc: 82.9%
# [BATCH 80] Avg Loss: 0.3981, Current Acc: 83.4%
# [BATCH 90] Avg Loss: 0.3960, Current Acc: 83.4%
# [BATCH 100] Avg Loss: 0.3992, Current Acc: 83.2%
# [BATCH 110] Avg Loss: 0.4026, Current Acc: 83.0%
# [BATCH 120] Avg Loss: 0.4027, Current Acc: 82.9%
# [BATCH 130] Avg Loss: 0.4019, Current Acc: 83.1%
# [BATCH 140] Avg Loss: 0.4027, Current Acc: 82.9%
# [BATCH 150] Avg Loss: 0.4009, Current Acc: 83.0%
# [BATCH 160] Avg Loss: 0.3994, Current Acc: 83.1%
# [BATCH 170] Avg Loss: 0.3984, Current Acc: 83.3%
# [BATCH 180] Avg Loss: 0.3938, Current Acc: 83.6%
# [BATCH 190] Avg Loss: 0.3947, Current Acc: 83.5%
# [BATCH 200] Avg Loss: 0.3940, Current Acc: 83.5%
# [BATCH 210] Avg Loss: 0.3945, Current Acc: 83.4%
# [BATCH 220] Avg Loss: 0.3938, Current Acc: 83.5%
# [BATCH 230] Avg Loss: 0.3929, Current Acc: 83.5%
# [BATCH 240] Avg Loss: 0.3903, Current Acc: 83.7%
# [BATCH 250] Avg Loss: 0.3866, Current Acc: 84.0%
# [BATCH 260] Avg Loss: 0.3855, Current Acc: 84.0%
# [BATCH 270] Avg Loss: 0.3864, Current Acc: 84.0%
# [BATCH 280] Avg Loss: 0.3881, Current Acc: 84.0%
# [BATCH 290] Avg Loss: 0.3887, Current Acc: 84.0%
# [BATCH 300] Avg Loss: 0.3874, Current Acc: 84.0%
# [BATCH 310] Avg Loss: 0.3874, Current Acc: 84.0%
# [BATCH 320] Avg Loss: 0.3865, Current Acc: 84.1%
# [BATCH 330] Avg Loss: 0.3864, Current Acc: 84.2%
# [BATCH 340] Avg Loss: 0.3864, Current Acc: 84.1%
# [BATCH 350] Avg Loss: 0.3887, Current Acc: 84.1%
# [BATCH 360] Avg Loss: 0.3886, Current Acc: 84.2%
# [BATCH 370] Avg Loss: 0.3898, Current Acc: 84.1%
# [BATCH 380] Avg Loss: 0.3893, Current Acc: 84.1%
# [BATCH 390] Avg Loss: 0.3893, Current Acc: 84.1%
# [BATCH 400] Avg Loss: 0.3886, Current Acc: 84.1%
# [BATCH 410] Avg Loss: 0.3895, Current Acc: 84.1%
# [BATCH 420] Avg Loss: 0.3894, Current Acc: 84.1%
# [BATCH 430] Avg Loss: 0.3888, Current Acc: 84.1%
# [BATCH 440] Avg Loss: 0.3875, Current Acc: 84.2%
# [BATCH 450] Avg Loss: 0.3869, Current Acc: 84.2%
# [BATCH 460] Avg Loss: 0.3902, Current Acc: 84.2%
# [BATCH 470] Avg Loss: 0.3885, Current Acc: 84.2%
# [BATCH 480] Avg Loss: 0.3882, Current Acc: 84.2%
# [BATCH 490] Avg Loss: 0.3875, Current Acc: 84.2%
# [BATCH 500] Avg Loss: 0.3862, Current Acc: 84.3%
# [BATCH 510] Avg Loss: 0.3863, Current Acc: 84.3%
# [BATCH 520] Avg Loss: 0.3849, Current Acc: 84.4%
# [BATCH 530] Avg Loss: 0.3861, Current Acc: 84.3%
# [BATCH 540] Avg Loss: 0.3858, Current Acc: 84.3%
#
# [EPOCH 3 SUMMARY]
#   Loss: 0.3855
#   Accuracy: 84.35%
#   Time: 375.1 seconds
# [VALIDATION] Loss: 0.2556, Accuracy: 89.76%
#
# [EPOCH 4/5] Starting...
# [BATCH 1] Loss: 0.3657, Acc: 84.4%, Time: 0.1s
# [INFO] First batch completed! Training continues...
# [BATCH 10] Avg Loss: 0.3487, Current Acc: 84.7%
# [BATCH 20] Avg Loss: 0.3729, Current Acc: 85.8%
# [BATCH 30] Avg Loss: 0.3746, Current Acc: 85.7%
# [BATCH 40] Avg Loss: 0.3652, Current Acc: 85.5%
# [BATCH 50] Avg Loss: 0.3640, Current Acc: 86.1%
# [BATCH 60] Avg Loss: 0.3641, Current Acc: 85.7%
# [BATCH 70] Avg Loss: 0.3606, Current Acc: 85.6%
# [BATCH 80] Avg Loss: 0.3613, Current Acc: 85.9%
# [BATCH 90] Avg Loss: 0.3582, Current Acc: 86.0%
# [BATCH 100] Avg Loss: 0.3520, Current Acc: 86.2%
# [BATCH 110] Avg Loss: 0.3512, Current Acc: 86.2%
# [BATCH 120] Avg Loss: 0.3517, Current Acc: 86.2%
# [BATCH 130] Avg Loss: 0.3533, Current Acc: 86.1%
# [BATCH 140] Avg Loss: 0.3514, Current Acc: 86.1%
# [BATCH 150] Avg Loss: 0.3528, Current Acc: 86.1%
# [BATCH 160] Avg Loss: 0.3549, Current Acc: 86.0%
# [BATCH 170] Avg Loss: 0.3531, Current Acc: 86.1%
# [BATCH 180] Avg Loss: 0.3528, Current Acc: 86.0%
# [BATCH 190] Avg Loss: 0.3516, Current Acc: 86.1%
# [BATCH 200] Avg Loss: 0.3516, Current Acc: 86.0%
# [BATCH 210] Avg Loss: 0.3500, Current Acc: 86.0%
# [BATCH 220] Avg Loss: 0.3530, Current Acc: 86.0%
# [BATCH 230] Avg Loss: 0.3512, Current Acc: 86.0%
# [BATCH 240] Avg Loss: 0.3504, Current Acc: 86.0%
# [BATCH 250] Avg Loss: 0.3514, Current Acc: 85.9%
# [BATCH 260] Avg Loss: 0.3498, Current Acc: 85.9%
# [BATCH 270] Avg Loss: 0.3517, Current Acc: 85.8%
# [BATCH 280] Avg Loss: 0.3505, Current Acc: 85.9%
# [BATCH 290] Avg Loss: 0.3523, Current Acc: 85.8%
# [BATCH 300] Avg Loss: 0.3501, Current Acc: 86.0%
# [BATCH 310] Avg Loss: 0.3501, Current Acc: 85.9%
# [BATCH 320] Avg Loss: 0.3505, Current Acc: 85.9%
# [BATCH 330] Avg Loss: 0.3503, Current Acc: 85.9%
# [BATCH 340] Avg Loss: 0.3490, Current Acc: 86.0%
# [BATCH 350] Avg Loss: 0.3467, Current Acc: 86.2%
# [BATCH 360] Avg Loss: 0.3475, Current Acc: 86.2%
# [BATCH 370] Avg Loss: 0.3489, Current Acc: 86.2%
# [BATCH 380] Avg Loss: 0.3500, Current Acc: 86.1%
# [BATCH 390] Avg Loss: 0.3485, Current Acc: 86.2%
# [BATCH 400] Avg Loss: 0.3487, Current Acc: 86.2%
# [BATCH 410] Avg Loss: 0.3475, Current Acc: 86.3%
# [BATCH 420] Avg Loss: 0.3462, Current Acc: 86.3%
# [BATCH 430] Avg Loss: 0.3455, Current Acc: 86.3%
# [BATCH 440] Avg Loss: 0.3452, Current Acc: 86.4%
# [BATCH 450] Avg Loss: 0.3446, Current Acc: 86.4%
# [BATCH 460] Avg Loss: 0.3434, Current Acc: 86.5%
# [BATCH 470] Avg Loss: 0.3423, Current Acc: 86.6%
# [BATCH 480] Avg Loss: 0.3414, Current Acc: 86.6%
# [BATCH 490] Avg Loss: 0.3410, Current Acc: 86.6%
# [BATCH 500] Avg Loss: 0.3421, Current Acc: 86.6%
# [BATCH 510] Avg Loss: 0.3409, Current Acc: 86.6%
# [BATCH 520] Avg Loss: 0.3399, Current Acc: 86.7%
# [BATCH 530] Avg Loss: 0.3396, Current Acc: 86.7%
# [BATCH 540] Avg Loss: 0.3394, Current Acc: 86.7%
#
# [EPOCH 4 SUMMARY]
#   Loss: 0.3392
#   Accuracy: 86.73%
#   Time: 382.7 seconds
# [VALIDATION] Loss: 0.2449, Accuracy: 91.52%
#
# [EPOCH 5/5] Starting...
# [BATCH 1] Loss: 0.3367, Acc: 84.4%, Time: 0.1s
# [INFO] First batch completed! Training continues...
# [BATCH 10] Avg Loss: 0.3750, Current Acc: 84.7%
# [BATCH 20] Avg Loss: 0.3256, Current Acc: 86.9%
# [BATCH 30] Avg Loss: 0.3193, Current Acc: 86.9%
# [BATCH 40] Avg Loss: 0.3282, Current Acc: 87.1%
# [BATCH 50] Avg Loss: 0.3314, Current Acc: 86.6%
# [BATCH 60] Avg Loss: 0.3221, Current Acc: 87.0%
# [BATCH 70] Avg Loss: 0.3159, Current Acc: 87.2%
# [BATCH 80] Avg Loss: 0.3151, Current Acc: 87.3%
# [BATCH 90] Avg Loss: 0.3091, Current Acc: 87.6%
# [BATCH 100] Avg Loss: 0.3059, Current Acc: 87.7%
# [BATCH 110] Avg Loss: 0.3073, Current Acc: 87.5%
# [BATCH 120] Avg Loss: 0.3027, Current Acc: 87.6%
# [BATCH 130] Avg Loss: 0.3014, Current Acc: 87.5%
# [BATCH 140] Avg Loss: 0.3001, Current Acc: 87.6%
# [BATCH 150] Avg Loss: 0.3023, Current Acc: 87.6%
# [BATCH 160] Avg Loss: 0.3010, Current Acc: 87.6%
# [BATCH 170] Avg Loss: 0.2991, Current Acc: 87.7%
# [BATCH 180] Avg Loss: 0.2998, Current Acc: 87.8%
# [BATCH 190] Avg Loss: 0.3001, Current Acc: 87.6%
# [BATCH 200] Avg Loss: 0.2973, Current Acc: 87.8%
# [BATCH 210] Avg Loss: 0.2964, Current Acc: 87.8%
# [BATCH 220] Avg Loss: 0.2958, Current Acc: 87.9%
# [BATCH 230] Avg Loss: 0.3001, Current Acc: 87.8%
# [BATCH 240] Avg Loss: 0.2997, Current Acc: 87.8%
# [BATCH 250] Avg Loss: 0.2999, Current Acc: 87.8%
# [BATCH 260] Avg Loss: 0.2983, Current Acc: 87.9%
# [BATCH 270] Avg Loss: 0.2985, Current Acc: 87.9%
# [BATCH 280] Avg Loss: 0.2995, Current Acc: 88.0%
# [BATCH 290] Avg Loss: 0.2983, Current Acc: 88.1%
# [BATCH 300] Avg Loss: 0.2987, Current Acc: 88.1%
# [BATCH 310] Avg Loss: 0.3004, Current Acc: 88.0%
# [BATCH 320] Avg Loss: 0.3008, Current Acc: 88.0%
# [BATCH 330] Avg Loss: 0.3021, Current Acc: 87.9%
# [BATCH 340] Avg Loss: 0.3005, Current Acc: 88.0%
# [BATCH 350] Avg Loss: 0.3011, Current Acc: 88.0%
# [BATCH 360] Avg Loss: 0.3018, Current Acc: 88.0%
# [BATCH 370] Avg Loss: 0.3029, Current Acc: 88.0%
# [BATCH 380] Avg Loss: 0.3015, Current Acc: 88.1%
# [BATCH 390] Avg Loss: 0.3007, Current Acc: 88.2%
# [BATCH 400] Avg Loss: 0.3005, Current Acc: 88.2%
# [BATCH 410] Avg Loss: 0.3012, Current Acc: 88.1%
# [BATCH 420] Avg Loss: 0.3018, Current Acc: 88.1%
# [BATCH 430] Avg Loss: 0.3024, Current Acc: 88.1%
# [BATCH 440] Avg Loss: 0.3021, Current Acc: 88.1%
# [BATCH 450] Avg Loss: 0.3006, Current Acc: 88.2%
# [BATCH 460] Avg Loss: 0.3017, Current Acc: 88.1%
# [BATCH 470] Avg Loss: 0.3030, Current Acc: 88.1%
# [BATCH 480] Avg Loss: 0.3033, Current Acc: 88.0%
# [BATCH 490] Avg Loss: 0.3043, Current Acc: 88.0%
# [BATCH 500] Avg Loss: 0.3043, Current Acc: 88.1%
# [BATCH 510] Avg Loss: 0.3057, Current Acc: 88.0%
# [BATCH 520] Avg Loss: 0.3055, Current Acc: 88.1%
# [BATCH 530] Avg Loss: 0.3064, Current Acc: 88.0%
# [BATCH 540] Avg Loss: 0.3057, Current Acc: 88.0%
#
# [EPOCH 5 SUMMARY]
#   Loss: 0.3053
#   Accuracy: 88.03%
#   Time: 520.2 seconds
# [VALIDATION] Loss: 0.2258, Accuracy: 90.72%
#
# ======================================================================
# TRAINING COMPLETE!
# Model saved as 'cancer_cnn_model.pth'
# Final Training Accuracy: 88.03%
# Final Validation Accuracy: 90.72%
# Total training time: 2719.9 seconds
